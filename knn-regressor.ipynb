# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import load_iris

# Load dataset
data = load_iris()

x = data.data
y = data.target   # numeric (0,1,2) → works for regression

# Split dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create KNN Regressor
knn_regressor = KNeighborsRegressor(
    n_neighbors=5,          # number of neighbors (default=5)
    weights='distance',    # 'uniform' or 'distance'
    algorithm='auto',      # 'auto', 'ball_tree', 'kd_tree', 'brute'
    leaf_size=30,          # affects speed (default=30)
    p=2,                   # power parameter (2 = Euclidean, 1 = Manhattan)
    metric='minkowski',    # distance metric
    n_jobs=-1              # use all CPU cores
)

# Train the model
knn_regressor.fit(x_train, y_train)

# Predict
y_pred = knn_regressor.predict(x_test)

# Evaluation metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R2 Score:", r2)
# Out:
# Mean Squared Error: 0.0050712937716575505
# Mean Absolute Error: 0.021455870146988177
# R2 Score: 0.9927437767973103
